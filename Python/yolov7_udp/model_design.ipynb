# %% [markdown]
# # Model architecture from yaml file.

# %%
# !python mine/model_architecture_check.py \
    --img 320 --batch 1 --channels 3     \
    --cfg cfg/training/yolov7-tiny.yaml
# Out:
# Here is Model.py
# /home/holidayj/anaconda3/envs/hj/lib/python3.13/site-packages/torch/functional.py:554: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4322.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#
# YAML file:
# /media/holidayj/Documents/github/ML/Python/yolov7_udp/cfg/training/yolov7-tiny.yaml
#
# PyTorch module tree:
# Model(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
# ...

# %% [markdown]
# # Plot dataset bounding box distribution.

# %%
# %matplotlib inline
import utils.plots
import matplotlib.pyplot as plt
from IPython.display import display
utils.plots.analyze_bbox_area_distribution("/media/holidayj/Documents/Data/Platform/final_dataset/Euljiro/0_2_Original_dataset_Euljiro_off_peak_inner_20201128_f1038_t1519/3_class/Euljiro_off_peak_TrainVal_balanced_2sec_plus_addition_1sec_FINAL_20260117/TrainVal")
fig = plt.gcf(); display(fig); plt.close(fig)
# Out:
# Total bounding boxes analyzed: 11523

# %% [markdown]
# # Creating mask.

# %%
import utils.datasets
utils.datasets.generate_binary_mask(
    labels_dir = "/media/holidayj/Documents/Data/Platform/final_dataset/Euljiro/0_2_Original_dataset_Euljiro_off_peak_inner_20201128_f1038_t1519/3_class/Euljiro_off_peak_TrainVal_balanced_2sec_plus_addition_1sec_FINAL_20260117/TrainVal", 
    resolution = 320,
    save_path  = "output/dataset_mask.png")
# Out:
# Saved precise binary mask to output/dataset_mask.png
